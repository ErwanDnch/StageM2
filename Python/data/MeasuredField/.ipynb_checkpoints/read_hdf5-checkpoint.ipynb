# %%
import opyf
import numpy as np
import matplotlib.pyplot as plt

# %%
coord, var = opyf.hdf5_Read("frame_2500_to_10404_with_step_4_and_shift_100.hdf5")

# %% [markdown]
# #### Coord
# 0 = T  coord[0][1][n], len 80
#
# 1 = X  coord[1][1][i], len 960
#
# 2 = Y  coord[2][1][j], len 540
# #### var
# 0 = Ux  var[0][1][0][j,i], shape 540x960
#
# 1 = Uy  var[1][1][0][j,i], shape 540x960

# %%
coord[0]
# Out:
# ['T_[s]',
#  array([ 2502.,  2602.,  2702.,  2802.,  2902.,  3002.,  3102.,  3202.,
#          3302.,  3402.,  3502.,  3602.,  3702.,  3802.,  3902.,  4002.,
#          4102.,  4202.,  4302.,  4402.,  4502.,  4602.,  4702.,  4802.,
#          4902.,  5002.,  5102.,  5202.,  5302.,  5402.,  5502.,  5602.,
#          5702.,  5802.,  5902.,  6002.,  6102.,  6202.,  6302.,  6402.,
#          6502.,  6602.,  6702.,  6802.,  6902.,  7002.,  7102.,  7202.,
#          7302.,  7402.,  7502.,  7602.,  7702.,  7802.,  7902.,  8002.,
#          8102.,  8202.,  8302.,  8402.,  8502.,  8602.,  8702.,  8802.,
#          8902.,  9002.,  9102.,  9202.,  9302.,  9402.,  9502.,  9602.,
#          9702.,  9802.,  9902., 10002., 10102., 10202., 10302., 10402.])]

# %% [markdown]
# ## Is the grid constant ? Can I use a dx instead of keeping X,Y

# %%
dt_base = coord[0][1][1] - coord[0][1][0]
for i,t in enumerate(coord[0][1]):
    if i==0:
        t_m = t
    else:
        if t-t_m!=dt_base:
            print(f"Ite {i}: dt DIFF\ndt = {t-t_m}")
        t_m = t

print("DONE")
print(dt_base)
# Out:
# DONE
# 100.0

# %%
dx_base = coord[1][1][1] - coord[1][1][0]
for i,x in enumerate(coord[1][1]):
    if i==0:
        x_m = x
    else:
        if x-x_m!=dx_base:
            print(f"Ite {i}: dx DIFF\ndx = {x-x_m}")
        x_m = x

print("DONE")
# Out:
# Ite 2: dx DIFF
# dx = 0.0028000000000000004
# Ite 4: dx DIFF
# dx = 0.0028000000000000004
# Ite 5: dx DIFF
# dx = 0.0028000000000000004
# Ite 6: dx DIFF
# dx = 0.0028000000000000004
# Ite 7: dx DIFF
# dx = 0.0028000000000000004
# Ite 8: dx DIFF
# dx = 0.002799999999999997
# Ite 9: dx DIFF
# dx = 0.0028000000000000004
# Ite 10: dx DIFF
# dx = 0.0028000000000000004
# Ite 11: dx DIFF
# dx = 0.0028000000000000004
# Ite 12: dx DIFF
# dx = 0.002799999999999997
# Ite 13: dx DIFF
# dx = 0.002800000000000004
# Ite 14: dx DIFF
# dx = 0.002799999999999997
# Ite 15: dx DIFF
# dx = 0.002800000000000004
# Ite 16: dx DIFF
# dx = 0.002799999999999997
# Ite 17: dx DIFF
# dx = 0.002800000000000004
# Ite 18: dx DIFF
# dx = 0.002799999999999997
# Ite 19: dx DIFF
# dx = 0.002800000000000004
# Ite 20: dx DIFF
# dx = 0.002799999999999997
# Ite 21: dx DIFF
# dx = 0.002799999999999997
# Ite 22: dx DIFF
# dx = 0.002800000000000004
# Ite 23: dx DIFF
# dx = 0.002799999999999997
# Ite 24: dx DIFF
# dx = 0.002799999999999997
# Ite 25: dx DIFF
# dx = 0.002800000000000011
# Ite 26: dx DIFF
# dx = 0.002799999999999997
# Ite 27: dx DIFF
# dx = 0.002799999999999997
# Ite 28: dx DIFF
# dx = 0.002799999999999997
# Ite 29: dx DIFF
# dx = 0.002799999999999997
# Ite 30: dx DIFF
# dx = 0.002800000000000011
# Ite 31: dx DIFF
# dx = 0.002799999999999997
# Ite 32: dx DIFF
# dx = 0.002799999999999997
# Ite 33: dx DIFF
# dx = 0.002799999999999997
# Ite 34: dx DIFF
# dx = 0.002800000000000011
# Ite 35: dx DIFF
# dx = 0.002799999999999997
# Ite 36: dx DIFF
# dx = 0.002799999999999997
# Ite 37: dx DIFF
# dx = 0.002799999999999997
# Ite 38: dx DIFF
# dx = 0.002799999999999997
# Ite 39: dx DIFF
# dx = 0.002800000000000011
# Ite 40: dx DIFF
# dx = 0.002799999999999997
# Ite 41: dx DIFF
# dx = 0.002799999999999997
# Ite 42: dx DIFF
# dx = 0.002799999999999997
# Ite 43: dx DIFF
# dx = 0.002800000000000011
# Ite 44: dx DIFF
# dx = 0.002799999999999997
# Ite 45: dx DIFF
# dx = 0.002799999999999983
# Ite 46: dx DIFF
# dx = 0.0028000000000000247
# Ite 47: dx DIFF
# dx = 0.002799999999999997
# Ite 48: dx DIFF
# dx = 0.002799999999999997
# Ite 49: dx DIFF
# dx = 0.002799999999999997
# Ite 50: dx DIFF
# dx = 0.002799999999999997
# Ite 51: dx DIFF
# dx = 0.002799999999999997
# Ite 52: dx DIFF
# dx = 0.002799999999999997
# Ite 53: dx DIFF
# dx = 0.002799999999999997
# Ite 54: dx DIFF
# dx = 0.002799999999999997
# Ite 55: dx DIFF
# dx = 0.0028000000000000247
# Ite 56: dx DIFF
# dx = 0.002799999999999997
# Ite 57: dx DIFF
# dx = 0.002799999999999997
# Ite 58: dx DIFF
# dx = 0.002799999999999997
# Ite 59: dx DIFF
# dx = 0.002799999999999997
# Ite 60: dx DIFF
# dx = 0.002799999999999997
# Ite 61: dx DIFF
# dx = 0.002799999999999997
# Ite 62: dx DIFF
# dx = 0.002799999999999997
# Ite 63: dx DIFF
# dx = 0.002799999999999997
# Ite 64: dx DIFF
# dx = 0.0028000000000000247
# Ite 65: dx DIFF
# dx = 0.002799999999999997
# Ite 66: dx DIFF
# dx = 0.002799999999999997
# Ite 67: dx DIFF
# dx = 0.002799999999999997
# Ite 68: dx DIFF
# dx = 0.002799999999999997
# Ite 69: dx DIFF
# dx = 0.002799999999999997
# Ite 70: dx DIFF
# dx = 0.002799999999999997
# Ite 71: dx DIFF
# dx = 0.002799999999999997
# Ite 72: dx DIFF
# dx = 0.002799999999999997
# Ite 73: dx DIFF
# dx = 0.0028000000000000247
# Ite 74: dx DIFF
# dx = 0.002799999999999997
# Ite 75: dx DIFF
# dx = 0.002799999999999997
# Ite 76: dx DIFF
# dx = 0.002799999999999997
# Ite 77: dx DIFF
# dx = 0.002799999999999997
# Ite 78: dx DIFF
# dx = 0.002799999999999997
# Ite 79: dx DIFF
# dx = 0.002799999999999997
# Ite 80: dx DIFF
# dx = 0.002799999999999997
# Ite 81: dx DIFF
# dx = 0.002799999999999997
# Ite 82: dx DIFF
# dx = 0.0028000000000000247
# Ite 83: dx DIFF
# dx = 0.002799999999999997
# Ite 84: dx DIFF
# dx = 0.002799999999999997
# Ite 85: dx DIFF
# dx = 0.002799999999999997
# Ite 86: dx DIFF
# dx = 0.002799999999999997
# Ite 87: dx DIFF
# dx = 0.002799999999999997
# Ite 88: dx DIFF
# dx = 0.002799999999999997
# Ite 89: dx DIFF
# dx = 0.002799999999999997
# Ite 90: dx DIFF
# dx = 0.0028000000000000247
# Ite 91: dx DIFF
# dx = 0.002799999999999969
# Ite 92: dx DIFF
# dx = 0.0028000000000000247
# Ite 93: dx DIFF
# dx = 0.002799999999999969
# Ite 94: dx DIFF
# dx = 0.0028000000000000247
# Ite 95: dx DIFF
# dx = 0.002799999999999969
# Ite 96: dx DIFF
# dx = 0.0028000000000000247
# Ite 97: dx DIFF
# dx = 0.0028000000000000247
# Ite 98: dx DIFF
# dx = 0.002799999999999969
# Ite 99: dx DIFF
# dx = 0.0028000000000000247
# Ite 100: dx DIFF
# dx = 0.002799999999999969
# Ite 101: dx DIFF
# dx = 0.0028000000000000247
# Ite 102: dx DIFF
# dx = 0.002799999999999969
# Ite 103: dx DIFF
# dx = 0.0028000000000000247
# Ite 104: dx DIFF
# dx = 0.002799999999999969
# Ite 105: dx DIFF
# dx = 0.0028000000000000247
# Ite 106: dx DIFF
# dx = 0.0028000000000000247
# Ite 107: dx DIFF
# dx = 0.002799999999999969
# Ite 108: dx DIFF
# dx = 0.0028000000000000247
# Ite 109: dx DIFF
# dx = 0.002799999999999969
# Ite 110: dx DIFF
# dx = 0.0028000000000000247
# Ite 111: dx DIFF
# dx = 0.002799999999999969
# Ite 112: dx DIFF
# dx = 0.0028000000000000247
# Ite 113: dx DIFF
# dx = 0.002799999999999969
# Ite 114: dx DIFF
# dx = 0.0028000000000000247
# Ite 115: dx DIFF
# dx = 0.0028000000000000247
# Ite 116: dx DIFF
# dx = 0.002799999999999969
# Ite 117: dx DIFF
# dx = 0.0028000000000000247
# Ite 118: dx DIFF
# dx = 0.002799999999999969
# Ite 119: dx DIFF
# dx = 0.0028000000000000247
# Ite 120: dx DIFF
# dx = 0.002799999999999969
# Ite 121: dx DIFF
# dx = 0.0028000000000000247
# Ite 122: dx DIFF
# dx = 0.002799999999999969
# Ite 123: dx DIFF
# dx = 0.0028000000000000247
# Ite 124: dx DIFF
# dx = 0.0028000000000000247
# Ite 125: dx DIFF
# dx = 0.002799999999999969
# Ite 126: dx DIFF
# dx = 0.0028000000000000247
# Ite 127: dx DIFF
# dx = 0.002799999999999969
# Ite 128: dx DIFF
# dx = 0.0028000000000000247
# Ite 129: dx DIFF
# dx = 0.002799999999999969
# Ite 130: dx DIFF
# dx = 0.0028000000000000247
# Ite 131: dx DIFF
# dx = 0.002799999999999969
# Ite 132: dx DIFF
# dx = 0.0028000000000000247
# Ite 133: dx DIFF
# dx = 0.0028000000000000247
# Ite 134: dx DIFF
# dx = 0.002799999999999969
# Ite 135: dx DIFF
# dx = 0.0028000000000000247
# Ite 136: dx DIFF
# dx = 0.002799999999999969
# Ite 137: dx DIFF
# dx = 0.0028000000000000247
# Ite 138: dx DIFF
# dx = 0.002799999999999969
# Ite 139: dx DIFF
# dx = 0.0028000000000000247
# Ite 140: dx DIFF
# dx = 0.002799999999999969
# Ite 141: dx DIFF
# dx = 0.0028000000000000247
# Ite 142: dx DIFF
# dx = 0.0028000000000000247
# Ite 143: dx DIFF
# dx = 0.002799999999999969
# Ite 144: dx DIFF
# dx = 0.0028000000000000247
# Ite 145: dx DIFF
# dx = 0.002799999999999969
# Ite 146: dx DIFF
# dx = 0.0028000000000000247
# Ite 147: dx DIFF
# dx = 0.002799999999999969
# Ite 148: dx DIFF
# dx = 0.0028000000000000247
# Ite 149: dx DIFF
# dx = 0.002799999999999969
# Ite 150: dx DIFF
# dx = 0.0028000000000000247
# Ite 151: dx DIFF
# dx = 0.0028000000000000247
# Ite 152: dx DIFF
# dx = 0.002799999999999969
# Ite 153: dx DIFF
# dx = 0.0028000000000000247
# Ite 154: dx DIFF
# dx = 0.002799999999999969
# Ite 155: dx DIFF
# dx = 0.0028000000000000247
# Ite 156: dx DIFF
# dx = 0.002799999999999969
# Ite 157: dx DIFF
# dx = 0.0028000000000000247
# Ite 158: dx DIFF
# dx = 0.002799999999999969
# Ite 159: dx DIFF
# dx = 0.0028000000000000247
# Ite 160: dx DIFF
# dx = 0.0028000000000000247
# Ite 161: dx DIFF
# dx = 0.002799999999999969
# Ite 162: dx DIFF
# dx = 0.0028000000000000247
# Ite 163: dx DIFF
# dx = 0.002799999999999969
# Ite 164: dx DIFF
# dx = 0.0028000000000000247
# Ite 165: dx DIFF
# dx = 0.002799999999999969
# Ite 166: dx DIFF
# dx = 0.0028000000000000247
# Ite 167: dx DIFF
# dx = 0.002799999999999969
# Ite 168: dx DIFF
# dx = 0.0028000000000000247
# Ite 169: dx DIFF
# dx = 0.0028000000000000247
# Ite 170: dx DIFF
# dx = 0.002799999999999969
# Ite 171: dx DIFF
# dx = 0.0028000000000000247
# Ite 172: dx DIFF
# dx = 0.002799999999999969
# Ite 173: dx DIFF
# dx = 0.0028000000000000247
# Ite 174: dx DIFF
# dx = 0.002799999999999969
# Ite 175: dx DIFF
# dx = 0.0028000000000000247
# Ite 176: dx DIFF
# dx = 0.002799999999999969
# Ite 177: dx DIFF
# dx = 0.0028000000000000247
# Ite 178: dx DIFF
# dx = 0.0028000000000000247
# Ite 179: dx DIFF
# dx = 0.0028000000000000247
# Ite 180: dx DIFF
# dx = 0.0027999999999999137
# Ite 181: dx DIFF
# dx = 0.0028000000000000247
# Ite 182: dx DIFF
# dx = 0.0028000000000000247
# Ite 183: dx DIFF
# dx = 0.0028000000000000247
# Ite 184: dx DIFF
# dx = 0.0027999999999999137
# Ite 185: dx DIFF
# dx = 0.0028000000000000247
# Ite 186: dx DIFF
# dx = 0.0028000000000000247
# Ite 187: dx DIFF
# dx = 0.0028000000000000247
# Ite 188: dx DIFF
# dx = 0.0028000000000000247
# Ite 189: dx DIFF
# dx = 0.0027999999999999137
# Ite 190: dx DIFF
# dx = 0.0028000000000000247
# Ite 191: dx DIFF
# dx = 0.0028000000000000247
# Ite 192: dx DIFF
# dx = 0.0028000000000000247
# Ite 193: dx DIFF
# dx = 0.0027999999999999137
# Ite 194: dx DIFF
# dx = 0.0028000000000000247
# Ite 195: dx DIFF
# dx = 0.0028000000000000247
# Ite 196: dx DIFF
# dx = 0.0028000000000000247
# Ite 197: dx DIFF
# dx = 0.0028000000000000247
# Ite 198: dx DIFF
# dx = 0.0027999999999999137
# Ite 199: dx DIFF
# dx = 0.0028000000000000247
# Ite 200: dx DIFF
# dx = 0.0028000000000000247
# Ite 201: dx DIFF
# dx = 0.0028000000000000247
# Ite 202: dx DIFF
# dx = 0.0027999999999999137
# Ite 203: dx DIFF
# dx = 0.0028000000000000247
# Ite 204: dx DIFF
# dx = 0.0028000000000000247
# Ite 205: dx DIFF
# dx = 0.0028000000000000247
# Ite 206: dx DIFF
# dx = 0.0028000000000000247
# Ite 207: dx DIFF
# dx = 0.0027999999999999137
# Ite 208: dx DIFF
# dx = 0.0028000000000000247
# Ite 209: dx DIFF
# dx = 0.0028000000000000247
# Ite 210: dx DIFF
# dx = 0.0028000000000000247
# Ite 211: dx DIFF
# dx = 0.0027999999999999137
# Ite 212: dx DIFF
# dx = 0.0028000000000000247
# Ite 213: dx DIFF
# dx = 0.0028000000000000247
# Ite 214: dx DIFF
# dx = 0.0028000000000000247
# Ite 215: dx DIFF
# dx = 0.0028000000000000247
# Ite 216: dx DIFF
# dx = 0.0027999999999999137
# Ite 217: dx DIFF
# dx = 0.0028000000000000247
# Ite 218: dx DIFF
# dx = 0.0028000000000000247
# Ite 219: dx DIFF
# dx = 0.0028000000000000247
# Ite 220: dx DIFF
# dx = 0.0027999999999999137
# Ite 221: dx DIFF
# dx = 0.0028000000000000247
# Ite 222: dx DIFF
# dx = 0.0028000000000000247
# Ite 223: dx DIFF
# dx = 0.0028000000000000247
# Ite 224: dx DIFF
# dx = 0.0028000000000000247
# Ite 225: dx DIFF
# dx = 0.0027999999999999137
# Ite 226: dx DIFF
# dx = 0.0028000000000000247
# Ite 227: dx DIFF
# dx = 0.0028000000000000247
# Ite 228: dx DIFF
# dx = 0.0028000000000000247
# Ite 229: dx DIFF
# dx = 0.0027999999999999137
# Ite 230: dx DIFF
# dx = 0.0028000000000000247
# Ite 231: dx DIFF
# dx = 0.0028000000000000247
# Ite 232: dx DIFF
# dx = 0.0028000000000000247
# Ite 233: dx DIFF
# dx = 0.0028000000000000247
# Ite 234: dx DIFF
# dx = 0.0027999999999999137
# Ite 235: dx DIFF
# dx = 0.0028000000000000247
# Ite 236: dx DIFF
# dx = 0.0028000000000000247
# Ite 237: dx DIFF
# dx = 0.0028000000000000247
# Ite 238: dx DIFF
# dx = 0.0027999999999999137
# Ite 239: dx DIFF
# dx = 0.0028000000000000247
# Ite 240: dx DIFF
# dx = 0.0028000000000000247
# Ite 241: dx DIFF
# dx = 0.0028000000000000247
# Ite 242: dx DIFF
# dx = 0.0028000000000000247
# Ite 243: dx DIFF
# dx = 0.0027999999999999137
# Ite 244: dx DIFF
# dx = 0.0028000000000000247
# Ite 245: dx DIFF
# dx = 0.0028000000000000247
# Ite 246: dx DIFF
# dx = 0.0028000000000000247
# Ite 247: dx DIFF
# dx = 0.0027999999999999137
# Ite 248: dx DIFF
# dx = 0.0028000000000000247
# Ite 249: dx DIFF
# dx = 0.0028000000000000247
# Ite 250: dx DIFF
# dx = 0.0028000000000000247
# Ite 251: dx DIFF
# dx = 0.0028000000000000247
# Ite 252: dx DIFF
# dx = 0.0027999999999999137
# Ite 253: dx DIFF
# dx = 0.0028000000000000247
# Ite 254: dx DIFF
# dx = 0.0028000000000000247
# Ite 255: dx DIFF
# dx = 0.0028000000000000247
# Ite 256: dx DIFF
# dx = 0.0027999999999999137
# Ite 257: dx DIFF
# dx = 0.0028000000000000247
# Ite 258: dx DIFF
# dx = 0.0028000000000000247
# Ite 259: dx DIFF
# dx = 0.0028000000000000247
# Ite 260: dx DIFF
# dx = 0.0027999999999999137
# Ite 261: dx DIFF
# dx = 0.0028000000000000247
# Ite 262: dx DIFF
# dx = 0.0028000000000000247
# Ite 263: dx DIFF
# dx = 0.0028000000000000247
# Ite 264: dx DIFF
# dx = 0.0028000000000000247
# Ite 265: dx DIFF
# dx = 0.0027999999999999137
# Ite 266: dx DIFF
# dx = 0.0028000000000000247
# Ite 267: dx DIFF
# dx = 0.0028000000000000247
# Ite 268: dx DIFF
# dx = 0.0028000000000000247
# Ite 269: dx DIFF
# dx = 0.0027999999999999137
# Ite 270: dx DIFF
# dx = 0.0028000000000000247
# Ite 271: dx DIFF
# dx = 0.0028000000000000247
# Ite 272: dx DIFF
# dx = 0.0028000000000000247
# Ite 273: dx DIFF
# dx = 0.0028000000000000247
# Ite 274: dx DIFF
# dx = 0.0027999999999999137
# Ite 275: dx DIFF
# dx = 0.0028000000000000247
# Ite 276: dx DIFF
# dx = 0.0028000000000000247
# Ite 277: dx DIFF
# dx = 0.0028000000000000247
# Ite 278: dx DIFF
# dx = 0.0027999999999999137
# Ite 279: dx DIFF
# dx = 0.0028000000000000247
# Ite 280: dx DIFF
# dx = 0.0028000000000000247
# Ite 281: dx DIFF
# dx = 0.0028000000000000247
# Ite 282: dx DIFF
# dx = 0.0028000000000000247
# Ite 283: dx DIFF
# dx = 0.0027999999999999137
# Ite 284: dx DIFF
# dx = 0.0028000000000000247
# Ite 285: dx DIFF
# dx = 0.0028000000000000247
# Ite 286: dx DIFF
# dx = 0.0028000000000000247
# Ite 287: dx DIFF
# dx = 0.0027999999999999137
# Ite 288: dx DIFF
# dx = 0.0028000000000000247
# Ite 289: dx DIFF
# dx = 0.0028000000000000247
# Ite 290: dx DIFF
# dx = 0.0028000000000000247
# Ite 291: dx DIFF
# dx = 0.0028000000000000247
# Ite 292: dx DIFF
# dx = 0.0027999999999999137
# Ite 293: dx DIFF
# dx = 0.0028000000000000247
# Ite 294: dx DIFF
# dx = 0.0028000000000000247
# Ite 295: dx DIFF
# dx = 0.0028000000000000247
# Ite 296: dx DIFF
# dx = 0.0027999999999999137
# Ite 297: dx DIFF
# dx = 0.0028000000000000247
# Ite 298: dx DIFF
# dx = 0.0028000000000000247
# Ite 299: dx DIFF
# dx = 0.0028000000000000247
# Ite 300: dx DIFF
# dx = 0.0028000000000000247
# Ite 301: dx DIFF
# dx = 0.0027999999999999137
# Ite 302: dx DIFF
# dx = 0.0028000000000000247
# Ite 303: dx DIFF
# dx = 0.0028000000000000247
# Ite 304: dx DIFF
# dx = 0.0028000000000000247
# Ite 305: dx DIFF
# dx = 0.0027999999999999137
# Ite 306: dx DIFF
# dx = 0.0028000000000000247
# Ite 307: dx DIFF
# dx = 0.0028000000000000247
# Ite 308: dx DIFF
# dx = 0.0028000000000000247
# Ite 309: dx DIFF
# dx = 0.0028000000000000247
# Ite 310: dx DIFF
# dx = 0.0027999999999999137
# Ite 311: dx DIFF
# dx = 0.0028000000000000247
# Ite 312: dx DIFF
# dx = 0.0028000000000000247
# Ite 313: dx DIFF
# dx = 0.0028000000000000247
# Ite 314: dx DIFF
# dx = 0.0027999999999999137
# Ite 315: dx DIFF
# dx = 0.0028000000000000247
# Ite 316: dx DIFF
# dx = 0.0028000000000000247
# Ite 317: dx DIFF
# dx = 0.0028000000000000247
# Ite 318: dx DIFF
# dx = 0.0028000000000000247
# Ite 319: dx DIFF
# dx = 0.0027999999999999137
# Ite 320: dx DIFF
# dx = 0.0028000000000000247
# Ite 321: dx DIFF
# dx = 0.0028000000000000247
# Ite 322: dx DIFF
# dx = 0.0028000000000000247
# Ite 323: dx DIFF
# dx = 0.0027999999999999137
# Ite 324: dx DIFF
# dx = 0.0028000000000000247
# Ite 325: dx DIFF
# dx = 0.0028000000000000247
# Ite 326: dx DIFF
# dx = 0.0028000000000000247
# Ite 327: dx DIFF
# dx = 0.0028000000000000247
# Ite 328: dx DIFF
# dx = 0.0027999999999999137
# Ite 329: dx DIFF
# dx = 0.0028000000000000247
# Ite 330: dx DIFF
# dx = 0.0028000000000000247
# Ite 331: dx DIFF
# dx = 0.0028000000000000247
# Ite 332: dx DIFF
# dx = 0.0027999999999999137
# Ite 333: dx DIFF
# dx = 0.0028000000000000247
# Ite 334: dx DIFF
# dx = 0.0028000000000000247
# Ite 335: dx DIFF
# dx = 0.0028000000000000247
# Ite 336: dx DIFF
# dx = 0.0028000000000000247
# Ite 337: dx DIFF
# dx = 0.0027999999999999137
# Ite 338: dx DIFF
# dx = 0.0028000000000000247
# Ite 339: dx DIFF
# dx = 0.0028000000000000247
# Ite 340: dx DIFF
# dx = 0.0028000000000000247
# Ite 341: dx DIFF
# dx = 0.0027999999999999137
# Ite 342: dx DIFF
# dx = 0.0028000000000000247
# Ite 343: dx DIFF
# dx = 0.0028000000000000247
# Ite 344: dx DIFF
# dx = 0.0028000000000000247
# Ite 345: dx DIFF
# dx = 0.0028000000000000247
# Ite 346: dx DIFF
# dx = 0.0027999999999999137
# Ite 347: dx DIFF
# dx = 0.0028000000000000247
# Ite 348: dx DIFF
# dx = 0.0028000000000000247
# Ite 349: dx DIFF
# dx = 0.0028000000000000247
# Ite 350: dx DIFF
# dx = 0.0027999999999999137
# Ite 351: dx DIFF
# dx = 0.0028000000000000247
# Ite 352: dx DIFF
# dx = 0.0028000000000000247
# Ite 353: dx DIFF
# dx = 0.0028000000000000247
# Ite 354: dx DIFF
# dx = 0.0028000000000000247
# Ite 355: dx DIFF
# dx = 0.0027999999999999137
# Ite 356: dx DIFF
# dx = 0.0028000000000000247
# Ite 357: dx DIFF
# dx = 0.0027999999999999137
# Ite 358: dx DIFF
# dx = 0.0028000000000001357
# Ite 359: dx DIFF
# dx = 0.0027999999999999137
# Ite 360: dx DIFF
# dx = 0.0028000000000001357
# Ite 361: dx DIFF
# dx = 0.0027999999999999137
# Ite 362: dx DIFF
# dx = 0.0027999999999999137
# Ite 363: dx DIFF
# dx = 0.0028000000000001357
# Ite 364: dx DIFF
# dx = 0.0027999999999999137
# Ite 365: dx DIFF
# dx = 0.0028000000000001357
# Ite 366: dx DIFF
# dx = 0.0027999999999999137
# Ite 367: dx DIFF
# dx = 0.0027999999999999137
# Ite 368: dx DIFF
# dx = 0.0028000000000001357
# Ite 369: dx DIFF
# dx = 0.0027999999999999137
# Ite 370: dx DIFF
# dx = 0.0028000000000001357
# Ite 371: dx DIFF
# dx = 0.0027999999999999137
# Ite 372: dx DIFF
# dx = 0.0027999999999999137
# Ite 373: dx DIFF
# dx = 0.0028000000000001357
# Ite 374: dx DIFF
# dx = 0.0027999999999999137
# Ite 375: dx DIFF
# dx = 0.0027999999999999137
# Ite 376: dx DIFF
# dx = 0.0028000000000001357
# Ite 377: dx DIFF
# dx = 0.0027999999999999137
# Ite 378: dx DIFF
# dx = 0.0028000000000001357
# Ite 379: dx DIFF
# dx = 0.0027999999999999137
# Ite 380: dx DIFF
# dx = 0.0027999999999999137
# Ite 381: dx DIFF
# dx = 0.0028000000000001357
# Ite 382: dx DIFF
# dx = 0.0027999999999999137
# Ite 383: dx DIFF
# dx = 0.0028000000000001357
# Ite 384: dx DIFF
# dx = 0.0027999999999999137
# Ite 385: dx DIFF
# dx = 0.0027999999999999137
# Ite 386: dx DIFF
# dx = 0.0028000000000001357
# Ite 387: dx DIFF
# dx = 0.0027999999999999137
# Ite 388: dx DIFF
# dx = 0.0027999999999999137
# Ite 389: dx DIFF
# dx = 0.0028000000000001357
# Ite 390: dx DIFF
# dx = 0.0027999999999999137
# Ite 391: dx DIFF
# dx = 0.0028000000000001357
# Ite 392: dx DIFF
# dx = 0.0027999999999999137
# Ite 393: dx DIFF
# dx = 0.0027999999999999137
# Ite 394: dx DIFF
# dx = 0.0028000000000001357
# Ite 395: dx DIFF
# dx = 0.0027999999999999137
# Ite 396: dx DIFF
# dx = 0.0028000000000001357
# Ite 397: dx DIFF
# dx = 0.0027999999999999137
# Ite 398: dx DIFF
# dx = 0.0027999999999999137
# Ite 399: dx DIFF
# dx = 0.0028000000000001357
# Ite 400: dx DIFF
# dx = 0.0027999999999999137
# Ite 401: dx DIFF
# dx = 0.0028000000000001357
# Ite 402: dx DIFF
# dx = 0.0027999999999999137
# Ite 403: dx DIFF
# dx = 0.0027999999999999137
# Ite 404: dx DIFF
# dx = 0.0028000000000001357
# Ite 405: dx DIFF
# dx = 0.0027999999999999137
# Ite 406: dx DIFF
# dx = 0.0027999999999999137
# Ite 407: dx DIFF
# dx = 0.0028000000000001357
# Ite 408: dx DIFF
# dx = 0.0027999999999999137
# Ite 409: dx DIFF
# dx = 0.0028000000000001357
# Ite 410: dx DIFF
# dx = 0.0027999999999999137
# Ite 411: dx DIFF
# dx = 0.0027999999999999137
# Ite 412: dx DIFF
# dx = 0.0028000000000001357
# Ite 413: dx DIFF
# dx = 0.0027999999999999137
# Ite 414: dx DIFF
# dx = 0.0028000000000001357
# Ite 415: dx DIFF
# dx = 0.0027999999999999137
# Ite 416: dx DIFF
# dx = 0.0027999999999999137
# Ite 417: dx DIFF
# dx = 0.0028000000000001357
# Ite 418: dx DIFF
# dx = 0.0027999999999999137
# Ite 419: dx DIFF
# dx = 0.0028000000000001357
# Ite 420: dx DIFF
# dx = 0.0027999999999999137
# Ite 421: dx DIFF
# dx = 0.0027999999999999137
# Ite 422: dx DIFF
# dx = 0.0028000000000001357
# Ite 423: dx DIFF
# dx = 0.0027999999999999137
# Ite 424: dx DIFF
# dx = 0.0027999999999999137
# Ite 425: dx DIFF
# dx = 0.0028000000000001357
# Ite 426: dx DIFF
# dx = 0.0027999999999999137
# Ite 427: dx DIFF
# dx = 0.0028000000000001357
# Ite 428: dx DIFF
# dx = 0.0027999999999999137
# Ite 429: dx DIFF
# dx = 0.0027999999999999137
# Ite 430: dx DIFF
# dx = 0.0028000000000001357
# Ite 431: dx DIFF
# dx = 0.0027999999999999137
# Ite 432: dx DIFF
# dx = 0.0028000000000001357
# Ite 433: dx DIFF
# dx = 0.0027999999999999137
# Ite 434: dx DIFF
# dx = 0.0027999999999999137
# Ite 435: dx DIFF
# dx = 0.0028000000000001357
# Ite 436: dx DIFF
# dx = 0.0027999999999999137
# Ite 437: dx DIFF
# dx = 0.0028000000000001357
# Ite 438: dx DIFF
# dx = 0.0027999999999999137
# Ite 439: dx DIFF
# dx = 0.0027999999999999137
# Ite 440: dx DIFF
# dx = 0.0028000000000001357
# Ite 441: dx DIFF
# dx = 0.0027999999999999137
# Ite 442: dx DIFF
# dx = 0.0027999999999999137
# Ite 443: dx DIFF
# dx = 0.0028000000000001357
# Ite 444: dx DIFF
# dx = 0.0027999999999999137
# Ite 445: dx DIFF
# dx = 0.0028000000000001357
# Ite 446: dx DIFF
# dx = 0.0027999999999999137
# Ite 447: dx DIFF
# dx = 0.0027999999999999137
# Ite 448: dx DIFF
# dx = 0.0028000000000001357
# Ite 449: dx DIFF
# dx = 0.0027999999999999137
# Ite 450: dx DIFF
# dx = 0.0028000000000001357
# Ite 451: dx DIFF
# dx = 0.0027999999999999137
# Ite 452: dx DIFF
# dx = 0.0027999999999999137
# Ite 453: dx DIFF
# dx = 0.0028000000000001357
# Ite 454: dx DIFF
# dx = 0.0027999999999999137
# Ite 455: dx DIFF
# dx = 0.0028000000000001357
# Ite 456: dx DIFF
# dx = 0.0027999999999999137
# Ite 457: dx DIFF
# dx = 0.0027999999999999137
# Ite 458: dx DIFF
# dx = 0.0028000000000001357
# Ite 459: dx DIFF
# dx = 0.0027999999999999137
# Ite 460: dx DIFF
# dx = 0.0027999999999999137
# Ite 461: dx DIFF
# dx = 0.0028000000000001357
# Ite 462: dx DIFF
# dx = 0.0027999999999999137
# Ite 463: dx DIFF
# dx = 0.0028000000000001357
# Ite 464: dx DIFF
# dx = 0.0027999999999999137
# Ite 465: dx DIFF
# dx = 0.0027999999999999137
# Ite 466: dx DIFF
# dx = 0.0028000000000001357
# Ite 467: dx DIFF
# dx = 0.0027999999999999137
# Ite 468: dx DIFF
# dx = 0.0028000000000001357
# Ite 469: dx DIFF
# dx = 0.0027999999999999137
# Ite 470: dx DIFF
# dx = 0.0027999999999999137
# Ite 471: dx DIFF
# dx = 0.0028000000000001357
# Ite 472: dx DIFF
# dx = 0.0027999999999999137
# Ite 473: dx DIFF
# dx = 0.0028000000000001357
# Ite 474: dx DIFF
# dx = 0.0027999999999999137
# Ite 475: dx DIFF
# dx = 0.0027999999999999137
# Ite 476: dx DIFF
# dx = 0.0028000000000001357
# Ite 477: dx DIFF
# dx = 0.0027999999999999137
# Ite 478: dx DIFF
# dx = 0.0027999999999999137
# Ite 479: dx DIFF
# dx = 0.0028000000000001357
# Ite 480: dx DIFF
# dx = 0.0027999999999999137
# Ite 481: dx DIFF
# dx = 0.0028000000000001357
# Ite 482: dx DIFF
# dx = 0.0027999999999999137
# Ite 483: dx DIFF
# dx = 0.0027999999999999137
# Ite 484: dx DIFF
# dx = 0.0028000000000001357
# Ite 485: dx DIFF
# dx = 0.0027999999999999137
# Ite 486: dx DIFF
# dx = 0.0028000000000001357
# Ite 487: dx DIFF
# dx = 0.0027999999999999137
# Ite 488: dx DIFF
# dx = 0.0027999999999999137
# Ite 489: dx DIFF
# dx = 0.0028000000000001357
# Ite 490: dx DIFF
# dx = 0.0027999999999999137
# Ite 491: dx DIFF
# dx = 0.0028000000000001357
# Ite 492: dx DIFF
# dx = 0.0027999999999999137
# Ite 493: dx DIFF
# dx = 0.0027999999999999137
# Ite 494: dx DIFF
# dx = 0.0028000000000001357
# Ite 495: dx DIFF
# dx = 0.0027999999999999137
# Ite 496: dx DIFF
# dx = 0.0027999999999999137
# Ite 497: dx DIFF
# dx = 0.0028000000000001357
# Ite 498: dx DIFF
# dx = 0.0027999999999999137
# Ite 499: dx DIFF
# dx = 0.0028000000000001357
# Ite 500: dx DIFF
# dx = 0.0027999999999999137
# Ite 501: dx DIFF
# dx = 0.0027999999999999137
# Ite 502: dx DIFF
# dx = 0.0028000000000001357
# Ite 503: dx DIFF
# dx = 0.0027999999999999137
# Ite 504: dx DIFF
# dx = 0.0028000000000001357
# Ite 505: dx DIFF
# dx = 0.0027999999999999137
# Ite 506: dx DIFF
# dx = 0.0027999999999999137
# Ite 507: dx DIFF
# dx = 0.0028000000000001357
# Ite 508: dx DIFF
# dx = 0.0027999999999999137
# Ite 509: dx DIFF
# dx = 0.0028000000000001357
# Ite 510: dx DIFF
# dx = 0.0027999999999999137
# Ite 511: dx DIFF
# dx = 0.0027999999999999137
# Ite 512: dx DIFF
# dx = 0.0028000000000001357
# Ite 513: dx DIFF
# dx = 0.0027999999999999137
# Ite 514: dx DIFF
# dx = 0.0027999999999999137
# Ite 515: dx DIFF
# dx = 0.0028000000000001357
# Ite 516: dx DIFF
# dx = 0.0027999999999999137
# Ite 517: dx DIFF
# dx = 0.0028000000000001357
# Ite 518: dx DIFF
# dx = 0.0027999999999999137
# Ite 519: dx DIFF
# dx = 0.0027999999999999137
# Ite 520: dx DIFF
# dx = 0.0028000000000001357
# Ite 521: dx DIFF
# dx = 0.0027999999999999137
# Ite 522: dx DIFF
# dx = 0.0028000000000001357
# Ite 523: dx DIFF
# dx = 0.0027999999999999137
# Ite 524: dx DIFF
# dx = 0.0027999999999999137
# Ite 525: dx DIFF
# dx = 0.0028000000000001357
# Ite 526: dx DIFF
# dx = 0.0027999999999999137
# Ite 527: dx DIFF
# dx = 0.0028000000000001357
# Ite 528: dx DIFF
# dx = 0.0027999999999999137
# Ite 529: dx DIFF
# dx = 0.0027999999999999137
# Ite 530: dx DIFF
# dx = 0.0028000000000001357
# Ite 531: dx DIFF
# dx = 0.0027999999999999137
# Ite 532: dx DIFF
# dx = 0.0027999999999999137
# Ite 533: dx DIFF
# dx = 0.0028000000000001357
# Ite 534: dx DIFF
# dx = 0.0027999999999999137
# Ite 535: dx DIFF
# dx = 0.0028000000000001357
# Ite 536: dx DIFF
# dx = 0.0027999999999999137
# Ite 537: dx DIFF
# dx = 0.0027999999999999137
# Ite 538: dx DIFF
# dx = 0.0028000000000001357
# Ite 539: dx DIFF
# dx = 0.0027999999999999137
# Ite 540: dx DIFF
# dx = 0.0028000000000001357
# Ite 541: dx DIFF
# dx = 0.0027999999999999137
# Ite 542: dx DIFF
# dx = 0.0027999999999999137
# Ite 543: dx DIFF
# dx = 0.0028000000000001357
# Ite 544: dx DIFF
# dx = 0.0027999999999999137
# Ite 545: dx DIFF
# dx = 0.0028000000000001357
# Ite 546: dx DIFF
# dx = 0.0027999999999999137
# Ite 547: dx DIFF
# dx = 0.0027999999999999137
# Ite 548: dx DIFF
# dx = 0.0028000000000001357
# Ite 549: dx DIFF
# dx = 0.0027999999999999137
# Ite 550: dx DIFF
# dx = 0.0027999999999999137
# Ite 551: dx DIFF
# dx = 0.0028000000000001357
# Ite 552: dx DIFF
# dx = 0.0027999999999999137
# Ite 553: dx DIFF
# dx = 0.0028000000000001357
# Ite 554: dx DIFF
# dx = 0.0027999999999999137
# Ite 555: dx DIFF
# dx = 0.0027999999999999137
# Ite 556: dx DIFF
# dx = 0.0028000000000001357
# Ite 557: dx DIFF
# dx = 0.0027999999999999137
# Ite 558: dx DIFF
# dx = 0.0028000000000001357
# Ite 559: dx DIFF
# dx = 0.0027999999999999137
# Ite 560: dx DIFF
# dx = 0.0027999999999999137
# Ite 561: dx DIFF
# dx = 0.0028000000000001357
# Ite 562: dx DIFF
# dx = 0.0027999999999999137
# Ite 563: dx DIFF
# dx = 0.0028000000000001357
# Ite 564: dx DIFF
# dx = 0.0027999999999999137
# Ite 565: dx DIFF
# dx = 0.0027999999999999137
# Ite 566: dx DIFF
# dx = 0.0028000000000001357
# Ite 567: dx DIFF
# dx = 0.0027999999999999137
# Ite 568: dx DIFF
# dx = 0.0027999999999999137
# Ite 569: dx DIFF
# dx = 0.0028000000000001357
# Ite 570: dx DIFF
# dx = 0.0027999999999999137
# Ite 571: dx DIFF
# dx = 0.0028000000000001357
# Ite 572: dx DIFF
# dx = 0.0027999999999999137
# Ite 573: dx DIFF
# dx = 0.0027999999999999137
# Ite 574: dx DIFF
# dx = 0.0028000000000001357
# Ite 575: dx DIFF
# dx = 0.0027999999999999137
# Ite 576: dx DIFF
# dx = 0.0028000000000001357
# Ite 577: dx DIFF
# dx = 0.0027999999999999137
# Ite 578: dx DIFF
# dx = 0.0027999999999999137
# Ite 579: dx DIFF
# dx = 0.0028000000000001357
# Ite 580: dx DIFF
# dx = 0.0027999999999999137
# Ite 581: dx DIFF
# dx = 0.0028000000000001357
# Ite 582: dx DIFF
# dx = 0.0027999999999999137
# Ite 583: dx DIFF
# dx = 0.0027999999999999137
# Ite 584: dx DIFF
# dx = 0.0028000000000001357
# Ite 585: dx DIFF
# dx = 0.0027999999999999137
# Ite 586: dx DIFF
# dx = 0.0027999999999999137
# Ite 587: dx DIFF
# dx = 0.0028000000000001357
# Ite 588: dx DIFF
# dx = 0.0027999999999999137
# Ite 589: dx DIFF
# dx = 0.0028000000000001357
# Ite 590: dx DIFF
# dx = 0.0027999999999999137
# Ite 591: dx DIFF
# dx = 0.0027999999999999137
# Ite 592: dx DIFF
# dx = 0.0028000000000001357
# Ite 593: dx DIFF
# dx = 0.0027999999999999137
# Ite 594: dx DIFF
# dx = 0.0028000000000001357
# Ite 595: dx DIFF
# dx = 0.0027999999999999137
# Ite 596: dx DIFF
# dx = 0.0027999999999999137
# Ite 597: dx DIFF
# dx = 0.0028000000000001357
# Ite 598: dx DIFF
# dx = 0.0027999999999999137
# Ite 599: dx DIFF
# dx = 0.0028000000000001357
# Ite 600: dx DIFF
# dx = 0.0027999999999999137
# Ite 601: dx DIFF
# dx = 0.0027999999999999137
# Ite 602: dx DIFF
# dx = 0.0028000000000001357
# Ite 603: dx DIFF
# dx = 0.0027999999999999137
# Ite 604: dx DIFF
# dx = 0.0027999999999999137
# Ite 605: dx DIFF
# dx = 0.0028000000000001357
# Ite 606: dx DIFF
# dx = 0.0027999999999999137
# Ite 607: dx DIFF
# dx = 0.0028000000000001357
# Ite 608: dx DIFF
# dx = 0.0027999999999999137
# Ite 609: dx DIFF
# dx = 0.0027999999999999137
# Ite 610: dx DIFF
# dx = 0.0028000000000001357
# Ite 611: dx DIFF
# dx = 0.0027999999999999137
# Ite 612: dx DIFF
# dx = 0.0028000000000001357
# Ite 613: dx DIFF
# dx = 0.0027999999999999137
# Ite 614: dx DIFF
# dx = 0.0027999999999999137
# Ite 615: dx DIFF
# dx = 0.0028000000000001357
# Ite 616: dx DIFF
# dx = 0.0027999999999999137
# Ite 617: dx DIFF
# dx = 0.0028000000000001357
# Ite 618: dx DIFF
# dx = 0.0027999999999999137
# Ite 619: dx DIFF
# dx = 0.0027999999999999137
# Ite 620: dx DIFF
# dx = 0.0028000000000001357
# Ite 621: dx DIFF
# dx = 0.0027999999999999137
# Ite 622: dx DIFF
# dx = 0.0027999999999999137
# Ite 623: dx DIFF
# dx = 0.0028000000000001357
# Ite 624: dx DIFF
# dx = 0.0027999999999999137
# Ite 625: dx DIFF
# dx = 0.0028000000000001357
# Ite 626: dx DIFF
# dx = 0.0027999999999999137
# Ite 627: dx DIFF
# dx = 0.0027999999999999137
# Ite 628: dx DIFF
# dx = 0.0028000000000001357
# Ite 629: dx DIFF
# dx = 0.0027999999999999137
# Ite 630: dx DIFF
# dx = 0.0028000000000001357
# Ite 631: dx DIFF
# dx = 0.0027999999999999137
# Ite 632: dx DIFF
# dx = 0.0027999999999999137
# Ite 633: dx DIFF
# dx = 0.0028000000000001357
# Ite 634: dx DIFF
# dx = 0.0027999999999999137
# Ite 635: dx DIFF
# dx = 0.0028000000000001357
# Ite 636: dx DIFF
# dx = 0.0027999999999999137
# Ite 637: dx DIFF
# dx = 0.0027999999999999137
# Ite 638: dx DIFF
# dx = 0.0028000000000001357
# Ite 639: dx DIFF
# dx = 0.0027999999999999137
# Ite 640: dx DIFF
# dx = 0.0027999999999999137
# Ite 641: dx DIFF
# dx = 0.0028000000000001357
# Ite 642: dx DIFF
# dx = 0.0027999999999999137
# Ite 643: dx DIFF
# dx = 0.0028000000000001357
# Ite 644: dx DIFF
# dx = 0.0027999999999999137
# Ite 645: dx DIFF
# dx = 0.0027999999999999137
# Ite 646: dx DIFF
# dx = 0.0028000000000001357
# Ite 647: dx DIFF
# dx = 0.0027999999999999137
# Ite 648: dx DIFF
# dx = 0.0028000000000001357
# Ite 649: dx DIFF
# dx = 0.0027999999999999137
# Ite 650: dx DIFF
# dx = 0.0027999999999999137
# Ite 651: dx DIFF
# dx = 0.0028000000000001357
# Ite 652: dx DIFF
# dx = 0.0027999999999999137
# Ite 653: dx DIFF
# dx = 0.0027999999999999137
# Ite 654: dx DIFF
# dx = 0.0028000000000001357
# Ite 655: dx DIFF
# dx = 0.0027999999999999137
# Ite 656: dx DIFF
# dx = 0.0028000000000001357
# Ite 657: dx DIFF
# dx = 0.0027999999999999137
# Ite 658: dx DIFF
# dx = 0.0027999999999999137
# Ite 659: dx DIFF
# dx = 0.0028000000000001357
# Ite 660: dx DIFF
# dx = 0.0027999999999999137
# Ite 661: dx DIFF
# dx = 0.0028000000000001357
# Ite 662: dx DIFF
# dx = 0.0027999999999999137
# Ite 663: dx DIFF
# dx = 0.0027999999999999137
# Ite 664: dx DIFF
# dx = 0.0028000000000001357
# Ite 665: dx DIFF
# dx = 0.0027999999999999137
# Ite 666: dx DIFF
# dx = 0.0028000000000001357
# Ite 667: dx DIFF
# dx = 0.0027999999999999137
# Ite 668: dx DIFF
# dx = 0.0027999999999999137
# Ite 669: dx DIFF
# dx = 0.0028000000000001357
# Ite 670: dx DIFF
# dx = 0.0027999999999999137
# Ite 671: dx DIFF
# dx = 0.0027999999999999137
# Ite 672: dx DIFF
# dx = 0.0028000000000001357
# Ite 673: dx DIFF
# dx = 0.0027999999999999137
# Ite 674: dx DIFF
# dx = 0.0028000000000001357
# Ite 675: dx DIFF
# dx = 0.0027999999999999137
# Ite 676: dx DIFF
# dx = 0.0027999999999999137
# Ite 677: dx DIFF
# dx = 0.0028000000000001357
# Ite 678: dx DIFF
# dx = 0.0027999999999999137
# Ite 679: dx DIFF
# dx = 0.0028000000000001357
# Ite 680: dx DIFF
# dx = 0.0027999999999999137
# Ite 681: dx DIFF
# dx = 0.0027999999999999137
# Ite 682: dx DIFF
# dx = 0.0028000000000001357
# Ite 683: dx DIFF
# dx = 0.0027999999999999137
# Ite 684: dx DIFF
# dx = 0.0028000000000001357
# Ite 685: dx DIFF
# dx = 0.0027999999999999137
# Ite 686: dx DIFF
# dx = 0.0027999999999999137
# Ite 687: dx DIFF
# dx = 0.0028000000000001357
# Ite 688: dx DIFF
# dx = 0.0027999999999999137
# Ite 689: dx DIFF
# dx = 0.0027999999999999137
# Ite 690: dx DIFF
# dx = 0.0028000000000001357
# Ite 691: dx DIFF
# dx = 0.0027999999999999137
# Ite 692: dx DIFF
# dx = 0.0028000000000001357
# Ite 693: dx DIFF
# dx = 0.0027999999999999137
# Ite 694: dx DIFF
# dx = 0.0027999999999999137
# Ite 695: dx DIFF
# dx = 0.0028000000000001357
# Ite 696: dx DIFF
# dx = 0.0027999999999999137
# Ite 697: dx DIFF
# dx = 0.0028000000000001357
# Ite 698: dx DIFF
# dx = 0.0027999999999999137
# Ite 699: dx DIFF
# dx = 0.0027999999999999137
# Ite 700: dx DIFF
# dx = 0.0028000000000001357
# Ite 701: dx DIFF
# dx = 0.0027999999999999137
# Ite 702: dx DIFF
# dx = 0.0028000000000001357
# Ite 703: dx DIFF
# dx = 0.0027999999999999137
# Ite 704: dx DIFF
# dx = 0.0027999999999999137
# Ite 705: dx DIFF
# dx = 0.0028000000000001357
# Ite 706: dx DIFF
# dx = 0.0027999999999999137
# Ite 707: dx DIFF
# dx = 0.0027999999999999137
# Ite 708: dx DIFF
# dx = 0.0028000000000001357
# Ite 709: dx DIFF
# dx = 0.0027999999999999137
# Ite 710: dx DIFF
# dx = 0.0028000000000001357
# Ite 711: dx DIFF
# dx = 0.0027999999999999137
# Ite 712: dx DIFF
# dx = 0.0027999999999999137
# Ite 713: dx DIFF
# dx = 0.0028000000000001357
# Ite 714: dx DIFF
# dx = 0.0027999999999999137
# Ite 715: dx DIFF
# dx = 0.0028000000000001357
# Ite 716: dx DIFF
# dx = 0.0027999999999996916
# Ite 717: dx DIFF
# dx = 0.0028000000000001357
# Ite 718: dx DIFF
# dx = 0.0028000000000001357
# Ite 719: dx DIFF
# dx = 0.0028000000000001357
# Ite 720: dx DIFF
# dx = 0.0027999999999996916
# Ite 721: dx DIFF
# dx = 0.0028000000000001357
# Ite 722: dx DIFF
# dx = 0.0028000000000001357
# Ite 723: dx DIFF
# dx = 0.0027999999999996916
# Ite 724: dx DIFF
# dx = 0.0028000000000001357
# Ite 725: dx DIFF
# dx = 0.0028000000000001357
# Ite 726: dx DIFF
# dx = 0.0027999999999996916
# Ite 727: dx DIFF
# dx = 0.0028000000000001357
# Ite 728: dx DIFF
# dx = 0.0028000000000001357
# Ite 729: dx DIFF
# dx = 0.0028000000000001357
# Ite 730: dx DIFF
# dx = 0.0027999999999996916
# Ite 731: dx DIFF
# dx = 0.0028000000000001357
# Ite 732: dx DIFF
# dx = 0.0028000000000001357
# Ite 733: dx DIFF
# dx = 0.0027999999999996916
# Ite 734: dx DIFF
# dx = 0.0028000000000001357
# Ite 735: dx DIFF
# dx = 0.0028000000000001357
# Ite 736: dx DIFF
# dx = 0.0027999999999996916
# Ite 737: dx DIFF
# dx = 0.0028000000000001357
# Ite 738: dx DIFF
# dx = 0.0028000000000001357
# Ite 739: dx DIFF
# dx = 0.0027999999999996916
# Ite 740: dx DIFF
# dx = 0.0028000000000001357
# Ite 741: dx DIFF
# dx = 0.0028000000000001357
# Ite 742: dx DIFF
# dx = 0.0028000000000001357
# Ite 743: dx DIFF
# dx = 0.0027999999999996916
# Ite 744: dx DIFF
# dx = 0.0028000000000001357
# Ite 745: dx DIFF
# dx = 0.0028000000000001357
# Ite 746: dx DIFF
# dx = 0.0027999999999996916
# Ite 747: dx DIFF
# dx = 0.0028000000000001357
# Ite 748: dx DIFF
# dx = 0.0028000000000001357
# Ite 749: dx DIFF
# dx = 0.0027999999999996916
# Ite 750: dx DIFF
# dx = 0.0028000000000001357
# Ite 751: dx DIFF
# dx = 0.0028000000000001357
# Ite 752: dx DIFF
# dx = 0.0027999999999996916
# Ite 753: dx DIFF
# dx = 0.0028000000000001357
# Ite 754: dx DIFF
# dx = 0.0028000000000001357
# Ite 755: dx DIFF
# dx = 0.0028000000000001357
# Ite 756: dx DIFF
# dx = 0.0027999999999996916
# Ite 757: dx DIFF
# dx = 0.0028000000000001357
# Ite 758: dx DIFF
# dx = 0.0028000000000001357
# Ite 759: dx DIFF
# dx = 0.0027999999999996916
# Ite 760: dx DIFF
# dx = 0.0028000000000001357
# Ite 761: dx DIFF
# dx = 0.0028000000000001357
# Ite 762: dx DIFF
# dx = 0.0027999999999996916
# Ite 763: dx DIFF
# dx = 0.0028000000000001357
# Ite 764: dx DIFF
# dx = 0.0028000000000001357
# Ite 765: dx DIFF
# dx = 0.0028000000000001357
# Ite 766: dx DIFF
# dx = 0.0027999999999996916
# Ite 767: dx DIFF
# dx = 0.0028000000000001357
# Ite 768: dx DIFF
# dx = 0.0028000000000001357
# Ite 769: dx DIFF
# dx = 0.0027999999999996916
# Ite 770: dx DIFF
# dx = 0.0028000000000001357
# Ite 771: dx DIFF
# dx = 0.0028000000000001357
# Ite 772: dx DIFF
# dx = 0.0027999999999996916
# Ite 773: dx DIFF
# dx = 0.0028000000000001357
# Ite 774: dx DIFF
# dx = 0.0028000000000001357
# Ite 775: dx DIFF
# dx = 0.0027999999999996916
# Ite 776: dx DIFF
# dx = 0.0028000000000001357
# Ite 777: dx DIFF
# dx = 0.0028000000000001357
# Ite 778: dx DIFF
# dx = 0.0028000000000001357
# Ite 779: dx DIFF
# dx = 0.0027999999999996916
# Ite 780: dx DIFF
# dx = 0.0028000000000001357
# Ite 781: dx DIFF
# dx = 0.0028000000000001357
# Ite 782: dx DIFF
# dx = 0.0027999999999996916
# Ite 783: dx DIFF
# dx = 0.0028000000000001357
# Ite 784: dx DIFF
# dx = 0.0028000000000001357
# Ite 785: dx DIFF
# dx = 0.0027999999999996916
# Ite 786: dx DIFF
# dx = 0.0028000000000001357
# Ite 787: dx DIFF
# dx = 0.0028000000000001357
# Ite 788: dx DIFF
# dx = 0.0027999999999996916
# Ite 789: dx DIFF
# dx = 0.0028000000000001357
# Ite 790: dx DIFF
# dx = 0.0028000000000001357
# Ite 791: dx DIFF
# dx = 0.0028000000000001357
# Ite 792: dx DIFF
# dx = 0.0027999999999996916
# Ite 793: dx DIFF
# dx = 0.0028000000000001357
# Ite 794: dx DIFF
# dx = 0.0028000000000001357
# Ite 795: dx DIFF
# dx = 0.0027999999999996916
# Ite 796: dx DIFF
# dx = 0.0028000000000001357
# Ite 797: dx DIFF
# dx = 0.0028000000000001357
# Ite 798: dx DIFF
# dx = 0.0027999999999996916
# Ite 799: dx DIFF
# dx = 0.0028000000000001357
# Ite 800: dx DIFF
# dx = 0.0028000000000001357
# Ite 801: dx DIFF
# dx = 0.0028000000000001357
# Ite 802: dx DIFF
# dx = 0.0027999999999996916
# Ite 803: dx DIFF
# dx = 0.0028000000000001357
# Ite 804: dx DIFF
# dx = 0.0028000000000001357
# Ite 805: dx DIFF
# dx = 0.0027999999999996916
# Ite 806: dx DIFF
# dx = 0.0028000000000001357
# Ite 807: dx DIFF
# dx = 0.0028000000000001357
# Ite 808: dx DIFF
# dx = 0.0027999999999996916
# Ite 809: dx DIFF
# dx = 0.0028000000000001357
# Ite 810: dx DIFF
# dx = 0.0028000000000001357
# Ite 811: dx DIFF
# dx = 0.0027999999999996916
# Ite 812: dx DIFF
# dx = 0.0028000000000001357
# Ite 813: dx DIFF
# dx = 0.0028000000000001357
# Ite 814: dx DIFF
# dx = 0.0028000000000001357
# Ite 815: dx DIFF
# dx = 0.0027999999999996916
# Ite 816: dx DIFF
# dx = 0.0028000000000001357
# Ite 817: dx DIFF
# dx = 0.0028000000000001357
# Ite 818: dx DIFF
# dx = 0.0027999999999996916
# Ite 819: dx DIFF
# dx = 0.0028000000000001357
# Ite 820: dx DIFF
# dx = 0.0028000000000001357
# Ite 821: dx DIFF
# dx = 0.0027999999999996916
# Ite 822: dx DIFF
# dx = 0.0028000000000001357
# Ite 823: dx DIFF
# dx = 0.0028000000000001357
# Ite 824: dx DIFF
# dx = 0.0027999999999996916
# Ite 825: dx DIFF
# dx = 0.0028000000000001357
# Ite 826: dx DIFF
# dx = 0.0028000000000001357
# Ite 827: dx DIFF
# dx = 0.0028000000000001357
# Ite 828: dx DIFF
# dx = 0.0027999999999996916
# Ite 829: dx DIFF
# dx = 0.0028000000000001357
# Ite 830: dx DIFF
# dx = 0.0028000000000001357
# Ite 831: dx DIFF
# dx = 0.0027999999999996916
# Ite 832: dx DIFF
# dx = 0.0028000000000001357
# Ite 833: dx DIFF
# dx = 0.0028000000000001357
# Ite 834: dx DIFF
# dx = 0.0027999999999996916
# Ite 835: dx DIFF
# dx = 0.0028000000000001357
# Ite 836: dx DIFF
# dx = 0.0028000000000001357
# Ite 837: dx DIFF
# dx = 0.0028000000000001357
# Ite 838: dx DIFF
# dx = 0.0027999999999996916
# Ite 839: dx DIFF
# dx = 0.0028000000000001357
# Ite 840: dx DIFF
# dx = 0.0028000000000001357
# Ite 841: dx DIFF
# dx = 0.0027999999999996916
# Ite 842: dx DIFF
# dx = 0.0028000000000001357
# Ite 843: dx DIFF
# dx = 0.0028000000000001357
# Ite 844: dx DIFF
# dx = 0.0027999999999996916
# Ite 845: dx DIFF
# dx = 0.0028000000000001357
# Ite 846: dx DIFF
# dx = 0.0028000000000001357
# Ite 847: dx DIFF
# dx = 0.0027999999999996916
# Ite 848: dx DIFF
# dx = 0.0028000000000001357
# Ite 849: dx DIFF
# dx = 0.0028000000000001357
# Ite 850: dx DIFF
# dx = 0.0028000000000001357
# Ite 851: dx DIFF
# dx = 0.0027999999999996916
# Ite 852: dx DIFF
# dx = 0.0028000000000001357
# Ite 853: dx DIFF
# dx = 0.0028000000000001357
# Ite 854: dx DIFF
# dx = 0.0027999999999996916
# Ite 855: dx DIFF
# dx = 0.0028000000000001357
# Ite 856: dx DIFF
# dx = 0.0028000000000001357
# Ite 857: dx DIFF
# dx = 0.0027999999999996916
# Ite 858: dx DIFF
# dx = 0.0028000000000001357
# Ite 859: dx DIFF
# dx = 0.0028000000000001357
# Ite 860: dx DIFF
# dx = 0.0027999999999996916
# Ite 861: dx DIFF
# dx = 0.0028000000000001357
# Ite 862: dx DIFF
# dx = 0.0028000000000001357
# Ite 863: dx DIFF
# dx = 0.0028000000000001357
# Ite 864: dx DIFF
# dx = 0.0027999999999996916
# Ite 865: dx DIFF
# dx = 0.0028000000000001357
# Ite 866: dx DIFF
# dx = 0.0028000000000001357
# Ite 867: dx DIFF
# dx = 0.0027999999999996916
# Ite 868: dx DIFF
# dx = 0.0028000000000001357
# Ite 869: dx DIFF
# dx = 0.0028000000000001357
# Ite 870: dx DIFF
# dx = 0.0027999999999996916
# Ite 871: dx DIFF
# dx = 0.0028000000000001357
# Ite 872: dx DIFF
# dx = 0.0028000000000001357
# Ite 873: dx DIFF
# dx = 0.0028000000000001357
# Ite 874: dx DIFF
# dx = 0.0027999999999996916
# Ite 875: dx DIFF
# dx = 0.0028000000000001357
# Ite 876: dx DIFF
# dx = 0.0028000000000001357
# Ite 877: dx DIFF
# dx = 0.0027999999999996916
# Ite 878: dx DIFF
# dx = 0.0028000000000001357
# Ite 879: dx DIFF
# dx = 0.0028000000000001357
# Ite 880: dx DIFF
# dx = 0.0027999999999996916
# Ite 881: dx DIFF
# dx = 0.0028000000000001357
# Ite 882: dx DIFF
# dx = 0.0028000000000001357
# Ite 883: dx DIFF
# dx = 0.0027999999999996916
# Ite 884: dx DIFF
# dx = 0.0028000000000001357
# Ite 885: dx DIFF
# dx = 0.0028000000000001357
# Ite 886: dx DIFF
# dx = 0.0028000000000001357
# Ite 887: dx DIFF
# dx = 0.0027999999999996916
# Ite 888: dx DIFF
# dx = 0.0028000000000001357
# Ite 889: dx DIFF
# dx = 0.0028000000000001357
# Ite 890: dx DIFF
# dx = 0.0027999999999996916
# Ite 891: dx DIFF
# dx = 0.0028000000000001357
# Ite 892: dx DIFF
# dx = 0.0028000000000001357
# Ite 893: dx DIFF
# dx = 0.0027999999999996916
# Ite 894: dx DIFF
# dx = 0.0028000000000001357
# Ite 895: dx DIFF
# dx = 0.0028000000000001357
# Ite 896: dx DIFF
# dx = 0.0027999999999996916
# Ite 897: dx DIFF
# dx = 0.0028000000000001357
# Ite 898: dx DIFF
# dx = 0.0028000000000001357
# Ite 899: dx DIFF
# dx = 0.0028000000000001357
# Ite 900: dx DIFF
# dx = 0.0027999999999996916
# Ite 901: dx DIFF
# dx = 0.0028000000000001357
# Ite 902: dx DIFF
# dx = 0.0028000000000001357
# Ite 903: dx DIFF
# dx = 0.0027999999999996916
# Ite 904: dx DIFF
# dx = 0.0028000000000001357
# Ite 905: dx DIFF
# dx = 0.0028000000000001357
# Ite 906: dx DIFF
# dx = 0.0027999999999996916
# Ite 907: dx DIFF
# dx = 0.0028000000000001357
# Ite 908: dx DIFF
# dx = 0.0028000000000001357
# Ite 909: dx DIFF
# dx = 0.0027999999999996916
# Ite 910: dx DIFF
# dx = 0.0028000000000001357
# Ite 911: dx DIFF
# dx = 0.0028000000000001357
# Ite 912: dx DIFF
# dx = 0.0028000000000001357
# Ite 913: dx DIFF
# dx = 0.0027999999999996916
# Ite 914: dx DIFF
# dx = 0.0028000000000001357
# Ite 915: dx DIFF
# dx = 0.0028000000000001357
# Ite 916: dx DIFF
# dx = 0.0027999999999996916
# Ite 917: dx DIFF
# dx = 0.0028000000000001357
# Ite 918: dx DIFF
# dx = 0.0028000000000001357
# Ite 919: dx DIFF
# dx = 0.0027999999999996916
# Ite 920: dx DIFF
# dx = 0.0028000000000001357
# Ite 921: dx DIFF
# dx = 0.0028000000000001357
# Ite 922: dx DIFF
# dx = 0.0028000000000001357
# Ite 923: dx DIFF
# dx = 0.0027999999999996916
# Ite 924: dx DIFF
# dx = 0.0028000000000001357
# Ite 925: dx DIFF
# dx = 0.0028000000000001357
# Ite 926: dx DIFF
# dx = 0.0027999999999996916
# Ite 927: dx DIFF
# dx = 0.0028000000000001357
# Ite 928: dx DIFF
# dx = 0.0028000000000001357
# Ite 929: dx DIFF
# dx = 0.0027999999999996916
# Ite 930: dx DIFF
# dx = 0.0028000000000001357
# Ite 931: dx DIFF
# dx = 0.0028000000000001357
# Ite 932: dx DIFF
# dx = 0.0027999999999996916
# Ite 933: dx DIFF
# dx = 0.0028000000000001357
# Ite 934: dx DIFF
# dx = 0.0028000000000001357
# Ite 935: dx DIFF
# dx = 0.0028000000000001357
# Ite 936: dx DIFF
# dx = 0.0027999999999996916
# Ite 937: dx DIFF
# dx = 0.0028000000000001357
# Ite 938: dx DIFF
# dx = 0.0028000000000001357
# Ite 939: dx DIFF
# dx = 0.0027999999999996916
# Ite 940: dx DIFF
# dx = 0.0028000000000001357
# Ite 941: dx DIFF
# dx = 0.0028000000000001357
# Ite 942: dx DIFF
# dx = 0.0027999999999996916
# Ite 943: dx DIFF
# dx = 0.0028000000000001357
# Ite 944: dx DIFF
# dx = 0.0028000000000001357
# Ite 945: dx DIFF
# dx = 0.0027999999999996916
# Ite 946: dx DIFF
# dx = 0.0028000000000001357
# Ite 947: dx DIFF
# dx = 0.0028000000000001357
# Ite 948: dx DIFF
# dx = 0.0028000000000001357
# Ite 949: dx DIFF
# dx = 0.0027999999999996916
# Ite 950: dx DIFF
# dx = 0.0028000000000001357
# Ite 951: dx DIFF
# dx = 0.0028000000000001357
# Ite 952: dx DIFF
# dx = 0.0027999999999996916
# Ite 953: dx DIFF
# dx = 0.0028000000000001357
# Ite 954: dx DIFF
# dx = 0.0028000000000001357
# Ite 955: dx DIFF
# dx = 0.0027999999999996916
# Ite 956: dx DIFF
# dx = 0.0028000000000001357
# Ite 957: dx DIFF
# dx = 0.0028000000000001357
# Ite 958: dx DIFF
# dx = 0.0028000000000001357
# Ite 959: dx DIFF
# dx = 0.0027999999999996916
# DONE

# %%
dy_base = coord[2][1][1] - coord[2][1][0]
for i,y in enumerate(coord[2][1]):
    if i==0:
        y_m = y
    else:
        if y-y_m!=dy_base:
            print(f"Ite {i}: dy DIFF\ndy = {y-y_m}")
        y_m = y

print("DONE")
# Out:
# Ite 2: dy DIFF
# dy = -0.0028000000000001357
# Ite 5: dy DIFF
# dy = -0.0028000000000001357
# Ite 7: dy DIFF
# dy = -0.0028000000000001357
# Ite 10: dy DIFF
# dy = -0.0028000000000001357
# Ite 13: dy DIFF
# dy = -0.0028000000000001357
# Ite 15: dy DIFF
# dy = -0.0028000000000001357
# Ite 18: dy DIFF
# dy = -0.0028000000000001357
# Ite 20: dy DIFF
# dy = -0.0028000000000001357
# Ite 23: dy DIFF
# dy = -0.0028000000000001357
# Ite 25: dy DIFF
# dy = -0.0028000000000001357
# Ite 28: dy DIFF
# dy = -0.0028000000000001357
# Ite 31: dy DIFF
# dy = -0.0028000000000001357
# Ite 33: dy DIFF
# dy = -0.0028000000000001357
# Ite 36: dy DIFF
# dy = -0.0028000000000001357
# Ite 38: dy DIFF
# dy = -0.0028000000000001357
# Ite 41: dy DIFF
# dy = -0.0028000000000001357
# Ite 43: dy DIFF
# dy = -0.0028000000000001357
# Ite 46: dy DIFF
# dy = -0.0028000000000001357
# Ite 49: dy DIFF
# dy = -0.0028000000000001357
# Ite 51: dy DIFF
# dy = -0.0028000000000001357
# Ite 54: dy DIFF
# dy = -0.0028000000000001357
# Ite 56: dy DIFF
# dy = -0.0028000000000001357
# Ite 59: dy DIFF
# dy = -0.0028000000000001357
# Ite 61: dy DIFF
# dy = -0.0028000000000001357
# Ite 64: dy DIFF
# dy = -0.0028000000000001357
# Ite 67: dy DIFF
# dy = -0.0028000000000001357
# Ite 69: dy DIFF
# dy = -0.0028000000000001357
# Ite 72: dy DIFF
# dy = -0.0028000000000001357
# Ite 74: dy DIFF
# dy = -0.0028000000000001357
# Ite 77: dy DIFF
# dy = -0.0028000000000001357
# Ite 79: dy DIFF
# dy = -0.0028000000000001357
# Ite 82: dy DIFF
# dy = -0.0028000000000001357
# Ite 85: dy DIFF
# dy = -0.0028000000000001357
# Ite 87: dy DIFF
# dy = -0.0028000000000001357
# Ite 90: dy DIFF
# dy = -0.0028000000000001357
# Ite 92: dy DIFF
# dy = -0.0028000000000001357
# Ite 95: dy DIFF
# dy = -0.0028000000000001357
# Ite 97: dy DIFF
# dy = -0.0028000000000001357
# Ite 100: dy DIFF
# dy = -0.0028000000000001357
# Ite 103: dy DIFF
# dy = -0.0028000000000001357
# Ite 105: dy DIFF
# dy = -0.0028000000000001357
# Ite 108: dy DIFF
# dy = -0.0028000000000001357
# Ite 110: dy DIFF
# dy = -0.0028000000000001357
# Ite 113: dy DIFF
# dy = -0.0028000000000001357
# Ite 115: dy DIFF
# dy = -0.0028000000000001357
# Ite 118: dy DIFF
# dy = -0.0028000000000001357
# Ite 121: dy DIFF
# dy = -0.0028000000000001357
# Ite 123: dy DIFF
# dy = -0.0028000000000001357
# Ite 126: dy DIFF
# dy = -0.0028000000000001357
# Ite 128: dy DIFF
# dy = -0.0028000000000001357
# Ite 131: dy DIFF
# dy = -0.0028000000000001357
# Ite 133: dy DIFF
# dy = -0.0028000000000001357
# Ite 136: dy DIFF
# dy = -0.0028000000000001357
# Ite 139: dy DIFF
# dy = -0.0028000000000001357
# Ite 141: dy DIFF
# dy = -0.0028000000000001357
# Ite 144: dy DIFF
# dy = -0.0028000000000001357
# Ite 146: dy DIFF
# dy = -0.0028000000000001357
# Ite 149: dy DIFF
# dy = -0.0028000000000001357
# Ite 151: dy DIFF
# dy = -0.0028000000000001357
# Ite 154: dy DIFF
# dy = -0.0028000000000001357
# Ite 157: dy DIFF
# dy = -0.0028000000000001357
# Ite 159: dy DIFF
# dy = -0.0028000000000001357
# Ite 162: dy DIFF
# dy = -0.0028000000000001357
# Ite 164: dy DIFF
# dy = -0.0028000000000001357
# Ite 167: dy DIFF
# dy = -0.0028000000000001357
# Ite 170: dy DIFF
# dy = -0.0028000000000001357
# Ite 172: dy DIFF
# dy = -0.0028000000000001357
# Ite 175: dy DIFF
# dy = -0.0028000000000001357
# Ite 177: dy DIFF
# dy = -0.0028000000000001357
# Ite 180: dy DIFF
# dy = -0.0028000000000001357
# Ite 182: dy DIFF
# dy = -0.0028000000000001357
# Ite 184: dy DIFF
# dy = -0.0028000000000000247
# Ite 186: dy DIFF
# dy = -0.0028000000000000247
# Ite 187: dy DIFF
# dy = -0.0028000000000000247
# Ite 188: dy DIFF
# dy = -0.0028000000000000247
# Ite 189: dy DIFF
# dy = -0.0028000000000000247
# Ite 191: dy DIFF
# dy = -0.0028000000000000247
# Ite 192: dy DIFF
# dy = -0.0028000000000000247
# Ite 193: dy DIFF
# dy = -0.0028000000000000247
# Ite 195: dy DIFF
# dy = -0.0028000000000000247
# Ite 196: dy DIFF
# dy = -0.0028000000000000247
# Ite 197: dy DIFF
# dy = -0.0028000000000000247
# Ite 198: dy DIFF
# dy = -0.0028000000000000247
# Ite 200: dy DIFF
# dy = -0.0028000000000000247
# Ite 201: dy DIFF
# dy = -0.0028000000000000247
# Ite 202: dy DIFF
# dy = -0.0028000000000000247
# Ite 204: dy DIFF
# dy = -0.0028000000000000247
# Ite 205: dy DIFF
# dy = -0.0028000000000000247
# Ite 206: dy DIFF
# dy = -0.0028000000000000247
# Ite 207: dy DIFF
# dy = -0.0028000000000000247
# Ite 209: dy DIFF
# dy = -0.0028000000000000247
# Ite 210: dy DIFF
# dy = -0.0028000000000000247
# Ite 211: dy DIFF
# dy = -0.0028000000000000247
# Ite 213: dy DIFF
# dy = -0.0028000000000000247
# Ite 214: dy DIFF
# dy = -0.0028000000000000247
# Ite 215: dy DIFF
# dy = -0.0028000000000000247
# Ite 216: dy DIFF
# dy = -0.0028000000000000247
# Ite 218: dy DIFF
# dy = -0.0028000000000000247
# Ite 219: dy DIFF
# dy = -0.0028000000000000247
# Ite 220: dy DIFF
# dy = -0.0028000000000000247
# Ite 222: dy DIFF
# dy = -0.0028000000000000247
# Ite 223: dy DIFF
# dy = -0.0028000000000000247
# Ite 224: dy DIFF
# dy = -0.0028000000000000247
# Ite 225: dy DIFF
# dy = -0.0028000000000000247
# Ite 227: dy DIFF
# dy = -0.0028000000000000247
# Ite 228: dy DIFF
# dy = -0.0028000000000000247
# Ite 229: dy DIFF
# dy = -0.0028000000000000247
# Ite 231: dy DIFF
# dy = -0.0028000000000000247
# Ite 232: dy DIFF
# dy = -0.0028000000000000247
# Ite 233: dy DIFF
# dy = -0.0028000000000000247
# Ite 234: dy DIFF
# dy = -0.0028000000000000247
# Ite 236: dy DIFF
# dy = -0.0028000000000000247
# Ite 237: dy DIFF
# dy = -0.0028000000000000247
# Ite 238: dy DIFF
# dy = -0.0028000000000000247
# Ite 240: dy DIFF
# dy = -0.0028000000000000247
# Ite 241: dy DIFF
# dy = -0.0028000000000000247
# Ite 242: dy DIFF
# dy = -0.0028000000000000247
# Ite 243: dy DIFF
# dy = -0.0028000000000000247
# Ite 245: dy DIFF
# dy = -0.0028000000000000247
# Ite 246: dy DIFF
# dy = -0.0028000000000000247
# Ite 247: dy DIFF
# dy = -0.0028000000000000247
# Ite 249: dy DIFF
# dy = -0.0028000000000000247
# Ite 250: dy DIFF
# dy = -0.0028000000000000247
# Ite 251: dy DIFF
# dy = -0.0028000000000000247
# Ite 252: dy DIFF
# dy = -0.0028000000000000247
# Ite 254: dy DIFF
# dy = -0.0028000000000000247
# Ite 255: dy DIFF
# dy = -0.0028000000000000247
# Ite 256: dy DIFF
# dy = -0.0028000000000000247
# Ite 258: dy DIFF
# dy = -0.0028000000000000247
# Ite 259: dy DIFF
# dy = -0.0028000000000000247
# Ite 260: dy DIFF
# dy = -0.0028000000000000247
# Ite 261: dy DIFF
# dy = -0.0028000000000000247
# Ite 263: dy DIFF
# dy = -0.0028000000000000247
# Ite 264: dy DIFF
# dy = -0.0028000000000000247
# Ite 265: dy DIFF
# dy = -0.0028000000000000247
# Ite 267: dy DIFF
# dy = -0.0028000000000000247
# Ite 268: dy DIFF
# dy = -0.0028000000000000247
# Ite 269: dy DIFF
# dy = -0.0028000000000000247
# Ite 270: dy DIFF
# dy = -0.0028000000000000247
# Ite 272: dy DIFF
# dy = -0.0028000000000000247
# Ite 273: dy DIFF
# dy = -0.0028000000000000247
# Ite 274: dy DIFF
# dy = -0.0028000000000000247
# Ite 276: dy DIFF
# dy = -0.0028000000000000247
# Ite 277: dy DIFF
# dy = -0.0028000000000000247
# Ite 278: dy DIFF
# dy = -0.0028000000000000247
# Ite 279: dy DIFF
# dy = -0.0028000000000000247
# Ite 281: dy DIFF
# dy = -0.0028000000000000247
# Ite 282: dy DIFF
# dy = -0.0028000000000000247
# Ite 283: dy DIFF
# dy = -0.0028000000000000247
# Ite 285: dy DIFF
# dy = -0.0028000000000000247
# Ite 286: dy DIFF
# dy = -0.0028000000000000247
# Ite 287: dy DIFF
# dy = -0.0028000000000000247
# Ite 289: dy DIFF
# dy = -0.0028000000000000247
# Ite 290: dy DIFF
# dy = -0.0028000000000000247
# Ite 291: dy DIFF
# dy = -0.0028000000000000247
# Ite 292: dy DIFF
# dy = -0.0028000000000000247
# Ite 294: dy DIFF
# dy = -0.0028000000000000247
# Ite 295: dy DIFF
# dy = -0.0028000000000000247
# Ite 296: dy DIFF
# dy = -0.0028000000000000247
# Ite 298: dy DIFF
# dy = -0.0028000000000000247
# Ite 299: dy DIFF
# dy = -0.0028000000000000247
# Ite 300: dy DIFF
# dy = -0.0028000000000000247
# Ite 301: dy DIFF
# dy = -0.0028000000000000247
# Ite 303: dy DIFF
# dy = -0.0028000000000000247
# Ite 304: dy DIFF
# dy = -0.0028000000000000247
# Ite 305: dy DIFF
# dy = -0.0028000000000000247
# Ite 307: dy DIFF
# dy = -0.0028000000000000247
# Ite 308: dy DIFF
# dy = -0.0028000000000000247
# Ite 309: dy DIFF
# dy = -0.0028000000000000247
# Ite 310: dy DIFF
# dy = -0.0028000000000000247
# Ite 312: dy DIFF
# dy = -0.0028000000000000247
# Ite 313: dy DIFF
# dy = -0.0028000000000000247
# Ite 314: dy DIFF
# dy = -0.0028000000000000247
# Ite 316: dy DIFF
# dy = -0.0028000000000000247
# Ite 317: dy DIFF
# dy = -0.0028000000000000247
# Ite 318: dy DIFF
# dy = -0.0028000000000000247
# Ite 319: dy DIFF
# dy = -0.0028000000000000247
# Ite 321: dy DIFF
# dy = -0.0028000000000000247
# Ite 322: dy DIFF
# dy = -0.0028000000000000247
# Ite 323: dy DIFF
# dy = -0.0028000000000000247
# Ite 325: dy DIFF
# dy = -0.0028000000000000247
# Ite 326: dy DIFF
# dy = -0.0028000000000000247
# Ite 327: dy DIFF
# dy = -0.0028000000000000247
# Ite 328: dy DIFF
# dy = -0.0028000000000000247
# Ite 330: dy DIFF
# dy = -0.0028000000000000247
# Ite 331: dy DIFF
# dy = -0.0028000000000000247
# Ite 332: dy DIFF
# dy = -0.0028000000000000247
# Ite 334: dy DIFF
# dy = -0.0028000000000000247
# Ite 335: dy DIFF
# dy = -0.0028000000000000247
# Ite 336: dy DIFF
# dy = -0.0028000000000000247
# Ite 337: dy DIFF
# dy = -0.0028000000000000247
# Ite 339: dy DIFF
# dy = -0.0028000000000000247
# Ite 340: dy DIFF
# dy = -0.0028000000000000247
# Ite 341: dy DIFF
# dy = -0.0028000000000000247
# Ite 343: dy DIFF
# dy = -0.0028000000000000247
# Ite 344: dy DIFF
# dy = -0.0028000000000000247
# Ite 345: dy DIFF
# dy = -0.0028000000000000247
# Ite 346: dy DIFF
# dy = -0.0028000000000000247
# Ite 348: dy DIFF
# dy = -0.0028000000000000247
# Ite 349: dy DIFF
# dy = -0.0028000000000000247
# Ite 350: dy DIFF
# dy = -0.0028000000000000247
# Ite 352: dy DIFF
# dy = -0.0028000000000000247
# Ite 353: dy DIFF
# dy = -0.0028000000000000247
# Ite 354: dy DIFF
# dy = -0.0028000000000000247
# Ite 355: dy DIFF
# dy = -0.0028000000000000247
# Ite 357: dy DIFF
# dy = -0.0028000000000000247
# Ite 358: dy DIFF
# dy = -0.0028000000000000247
# Ite 359: dy DIFF
# dy = -0.0028000000000000247
# Ite 361: dy DIFF
# dy = -0.0028000000000000247
# Ite 362: dy DIFF
# dy = -0.0028000000000000247
# Ite 363: dy DIFF
# dy = -0.0028000000000000247
# Ite 364: dy DIFF
# dy = -0.002799999999999969
# Ite 365: dy DIFF
# dy = -0.0028000000000000247
# Ite 366: dy DIFF
# dy = -0.002799999999999969
# Ite 367: dy DIFF
# dy = -0.0028000000000000247
# Ite 368: dy DIFF
# dy = -0.002799999999999969
# Ite 369: dy DIFF
# dy = -0.0028000000000000247
# Ite 370: dy DIFF
# dy = -0.002799999999999969
# Ite 371: dy DIFF
# dy = -0.0028000000000000247
# Ite 372: dy DIFF
# dy = -0.0028000000000000247
# Ite 373: dy DIFF
# dy = -0.002799999999999969
# Ite 374: dy DIFF
# dy = -0.0028000000000000247
# Ite 375: dy DIFF
# dy = -0.002799999999999969
# Ite 376: dy DIFF
# dy = -0.0028000000000000247
# Ite 377: dy DIFF
# dy = -0.002799999999999969
# Ite 378: dy DIFF
# dy = -0.0028000000000000247
# Ite 379: dy DIFF
# dy = -0.002799999999999969
# Ite 380: dy DIFF
# dy = -0.0028000000000000247
# Ite 381: dy DIFF
# dy = -0.0028000000000000247
# Ite 382: dy DIFF
# dy = -0.002799999999999969
# Ite 383: dy DIFF
# dy = -0.0028000000000000247
# Ite 384: dy DIFF
# dy = -0.002799999999999969
# Ite 385: dy DIFF
# dy = -0.0028000000000000247
# Ite 386: dy DIFF
# dy = -0.002799999999999969
# Ite 387: dy DIFF
# dy = -0.0028000000000000247
# Ite 388: dy DIFF
# dy = -0.002799999999999969
# Ite 389: dy DIFF
# dy = -0.0028000000000000247
# Ite 390: dy DIFF
# dy = -0.0028000000000000247
# Ite 391: dy DIFF
# dy = -0.002799999999999969
# Ite 392: dy DIFF
# dy = -0.0028000000000000247
# Ite 393: dy DIFF
# dy = -0.002799999999999969
# Ite 394: dy DIFF
# dy = -0.0028000000000000247
# Ite 395: dy DIFF
# dy = -0.002799999999999969
# Ite 396: dy DIFF
# dy = -0.0028000000000000247
# Ite 397: dy DIFF
# dy = -0.002799999999999969
# Ite 398: dy DIFF
# dy = -0.0028000000000000247
# Ite 399: dy DIFF
# dy = -0.0028000000000000247
# Ite 400: dy DIFF
# dy = -0.002799999999999969
# Ite 401: dy DIFF
# dy = -0.0028000000000000247
# Ite 402: dy DIFF
# dy = -0.002799999999999969
# Ite 403: dy DIFF
# dy = -0.0028000000000000247
# Ite 404: dy DIFF
# dy = -0.002799999999999969
# Ite 405: dy DIFF
# dy = -0.0028000000000000247
# Ite 406: dy DIFF
# dy = -0.002799999999999969
# Ite 407: dy DIFF
# dy = -0.0028000000000000247
# Ite 408: dy DIFF
# dy = -0.0028000000000000247
# Ite 409: dy DIFF
# dy = -0.002799999999999969
# Ite 410: dy DIFF
# dy = -0.0028000000000000247
# Ite 411: dy DIFF
# dy = -0.002799999999999969
# Ite 412: dy DIFF
# dy = -0.0028000000000000247
# Ite 413: dy DIFF
# dy = -0.002799999999999969
# Ite 414: dy DIFF
# dy = -0.0028000000000000247
# Ite 415: dy DIFF
# dy = -0.002799999999999969
# Ite 416: dy DIFF
# dy = -0.0028000000000000247
# Ite 417: dy DIFF
# dy = -0.0028000000000000247
# Ite 418: dy DIFF
# dy = -0.002799999999999969
# Ite 419: dy DIFF
# dy = -0.0028000000000000247
# Ite 420: dy DIFF
# dy = -0.002799999999999969
# Ite 421: dy DIFF
# dy = -0.0028000000000000247
# Ite 422: dy DIFF
# dy = -0.002799999999999969
# Ite 423: dy DIFF
# dy = -0.0028000000000000247
# Ite 424: dy DIFF
# dy = -0.002799999999999969
# Ite 425: dy DIFF
# dy = -0.0028000000000000247
# Ite 426: dy DIFF
# dy = -0.0028000000000000247
# Ite 427: dy DIFF
# dy = -0.002799999999999969
# Ite 428: dy DIFF
# dy = -0.0028000000000000247
# Ite 429: dy DIFF
# dy = -0.002799999999999969
# Ite 430: dy DIFF
# dy = -0.0028000000000000247
# Ite 431: dy DIFF
# dy = -0.002799999999999969
# Ite 432: dy DIFF
# dy = -0.0028000000000000247
# Ite 433: dy DIFF
# dy = -0.002799999999999969
# Ite 434: dy DIFF
# dy = -0.0028000000000000247
# Ite 435: dy DIFF
# dy = -0.0028000000000000247
# Ite 436: dy DIFF
# dy = -0.002799999999999969
# Ite 437: dy DIFF
# dy = -0.0028000000000000247
# Ite 438: dy DIFF
# dy = -0.002799999999999969
# Ite 439: dy DIFF
# dy = -0.0028000000000000247
# Ite 440: dy DIFF
# dy = -0.002799999999999969
# Ite 441: dy DIFF
# dy = -0.0028000000000000247
# Ite 442: dy DIFF
# dy = -0.002799999999999969
# Ite 443: dy DIFF
# dy = -0.0028000000000000247
# Ite 444: dy DIFF
# dy = -0.0028000000000000247
# Ite 445: dy DIFF
# dy = -0.002799999999999969
# Ite 446: dy DIFF
# dy = -0.0028000000000000247
# Ite 447: dy DIFF
# dy = -0.002799999999999969
# Ite 448: dy DIFF
# dy = -0.0028000000000000247
# Ite 449: dy DIFF
# dy = -0.002799999999999969
# Ite 450: dy DIFF
# dy = -0.0028000000000000247
# Ite 451: dy DIFF
# dy = -0.002799999999999997
# Ite 452: dy DIFF
# dy = -0.002799999999999997
# Ite 453: dy DIFF
# dy = -0.002799999999999997
# Ite 454: dy DIFF
# dy = -0.002799999999999997
# Ite 455: dy DIFF
# dy = -0.002799999999999997
# Ite 456: dy DIFF
# dy = -0.002799999999999997
# Ite 457: dy DIFF
# dy = -0.002799999999999997
# Ite 458: dy DIFF
# dy = -0.0028000000000000247
# Ite 459: dy DIFF
# dy = -0.002799999999999997
# Ite 460: dy DIFF
# dy = -0.002799999999999997
# Ite 461: dy DIFF
# dy = -0.002799999999999997
# Ite 462: dy DIFF
# dy = -0.002799999999999997
# Ite 463: dy DIFF
# dy = -0.002799999999999997
# Ite 464: dy DIFF
# dy = -0.002799999999999997
# Ite 465: dy DIFF
# dy = -0.002799999999999997
# Ite 466: dy DIFF
# dy = -0.002799999999999997
# Ite 467: dy DIFF
# dy = -0.0028000000000000247
# Ite 468: dy DIFF
# dy = -0.002799999999999997
# Ite 469: dy DIFF
# dy = -0.002799999999999997
# Ite 470: dy DIFF
# dy = -0.002799999999999997
# Ite 471: dy DIFF
# dy = -0.002799999999999997
# Ite 472: dy DIFF
# dy = -0.002799999999999997
# Ite 473: dy DIFF
# dy = -0.002799999999999997
# Ite 474: dy DIFF
# dy = -0.002799999999999997
# Ite 475: dy DIFF
# dy = -0.002799999999999997
# Ite 476: dy DIFF
# dy = -0.0028000000000000247
# Ite 477: dy DIFF
# dy = -0.002799999999999997
# Ite 478: dy DIFF
# dy = -0.002799999999999997
# Ite 479: dy DIFF
# dy = -0.002799999999999997
# Ite 480: dy DIFF
# dy = -0.002799999999999997
# Ite 481: dy DIFF
# dy = -0.002799999999999997
# Ite 482: dy DIFF
# dy = -0.002799999999999997
# Ite 483: dy DIFF
# dy = -0.002799999999999997
# Ite 484: dy DIFF
# dy = -0.002799999999999997
# Ite 485: dy DIFF
# dy = -0.0028000000000000247
# Ite 486: dy DIFF
# dy = -0.002799999999999997
# Ite 487: dy DIFF
# dy = -0.002799999999999997
# Ite 488: dy DIFF
# dy = -0.002799999999999997
# Ite 489: dy DIFF
# dy = -0.002799999999999997
# Ite 490: dy DIFF
# dy = -0.002799999999999997
# Ite 491: dy DIFF
# dy = -0.002799999999999997
# Ite 492: dy DIFF
# dy = -0.002799999999999997
# Ite 493: dy DIFF
# dy = -0.002799999999999997
# Ite 494: dy DIFF
# dy = -0.0028000000000000247
# Ite 495: dy DIFF
# dy = -0.002799999999999983
# Ite 496: dy DIFF
# dy = -0.002799999999999997
# Ite 497: dy DIFF
# dy = -0.002800000000000011
# Ite 498: dy DIFF
# dy = -0.002799999999999997
# Ite 499: dy DIFF
# dy = -0.002799999999999997
# Ite 500: dy DIFF
# dy = -0.002799999999999997
# Ite 501: dy DIFF
# dy = -0.002800000000000011
# Ite 502: dy DIFF
# dy = -0.002799999999999997
# Ite 503: dy DIFF
# dy = -0.002799999999999997
# Ite 504: dy DIFF
# dy = -0.002799999999999997
# Ite 505: dy DIFF
# dy = -0.002799999999999997
# Ite 506: dy DIFF
# dy = -0.002800000000000011
# Ite 507: dy DIFF
# dy = -0.002799999999999997
# Ite 508: dy DIFF
# dy = -0.002799999999999997
# Ite 509: dy DIFF
# dy = -0.002799999999999997
# Ite 510: dy DIFF
# dy = -0.002800000000000011
# Ite 511: dy DIFF
# dy = -0.002799999999999997
# Ite 512: dy DIFF
# dy = -0.002799999999999997
# Ite 513: dy DIFF
# dy = -0.002799999999999997
# Ite 514: dy DIFF
# dy = -0.002799999999999997
# Ite 515: dy DIFF
# dy = -0.002800000000000011
# Ite 516: dy DIFF
# dy = -0.002799999999999997
# Ite 517: dy DIFF
# dy = -0.002799999999999997
# Ite 518: dy DIFF
# dy = -0.002800000000000004
# Ite 519: dy DIFF
# dy = -0.002799999999999997
# Ite 520: dy DIFF
# dy = -0.002799999999999997
# Ite 521: dy DIFF
# dy = -0.002800000000000004
# Ite 522: dy DIFF
# dy = -0.002799999999999997
# Ite 523: dy DIFF
# dy = -0.002800000000000004
# Ite 524: dy DIFF
# dy = -0.002799999999999997
# Ite 525: dy DIFF
# dy = -0.002800000000000004
# Ite 526: dy DIFF
# dy = -0.002799999999999997
# Ite 527: dy DIFF
# dy = -0.002800000000000004
# Ite 528: dy DIFF
# dy = -0.002799999999999997
# Ite 529: dy DIFF
# dy = -0.0028000000000000004
# Ite 530: dy DIFF
# dy = -0.0028000000000000004
# Ite 531: dy DIFF
# dy = -0.0028000000000000004
# Ite 532: dy DIFF
# dy = -0.002799999999999997
# Ite 533: dy DIFF
# dy = -0.0028000000000000004
# Ite 534: dy DIFF
# dy = -0.0028000000000000004
# Ite 535: dy DIFF
# dy = -0.0028000000000000004
# Ite 536: dy DIFF
# dy = -0.0028000000000000004
# Ite 537: dy DIFF
# dy = -0.0027999999999999995
# Ite 538: dy DIFF
# dy = -0.0028000000000000004
# Ite 539: dy DIFF
# dy = -0.0027999999999999995
# DONE

# %%
estim = 0.0028
diff_max = 0
for i,x in enumerate(coord[1][1]):
    if i==0:
        x_m = x
    else:
        if x-x_m - estim> diff_max:
            diff_max = x-x_m - estim
            print(x)
            print(x_m)
            print(f"New max diff: i {i} max diff {diff_max}")
        x_m = x

print(diff_max/estim*100)
print("We will assume dx = ", estim)
# Out:
# 0.007
# 0.0042
# New max diff: i 2 max diff 4.336808689942018e-19
# 0.0378
# 0.034999999999999996
# New max diff: i 13 max diff 3.903127820947816e-18
# 0.0714
# 0.0686
# New max diff: i 25 max diff 1.0842021724855044e-17
# 0.1302
# 0.12739999999999999
# New max diff: i 46 max diff 2.47198095326695e-17
# 1.0038
# 1.001
# New max diff: i 358 max diff 1.3574211199518516e-16
# 4.847932571256613e-12
# We will assume dx =  0.0028

# %%
estim = -0.0028
diff_may = 0
for i,y in enumerate(coord[2][1]):
    if i==0:
        y_m = y
    else:
        if y-y_m - estim> diff_may:
            diff_may = y-y_m - estim
            print(y)
            print(y_m)
            print(f"New may diff: i {i} may diff {diff_may}")
        y_m = y

print(diff_may/estim*100)
print("We will assume dy = ", estim)
# Out:
# 1.5078
# 1.5106
# New may diff: i 1 may diff 8.630249292984615e-17
# -3.082231890351648e-12
# We will assume dy =  -0.0028

# %%
arr = np.load("../NSFlume90s/numpy/data_2.npy")

# %%
np.shape(arr)
# Out:
# (256, 256, 5)

# %%
shape = (len(coord[1][1]), len(coord[2][1]), 2)
array = np.zeros(shape)
array[:,:,0] = var[0][1][0].T
array[:,:,1] = var[1][1][0].T

v_field = np.zeros((540,960,2))
v_field[:,:,0] = array[:,:,0].T
v_field[:,:,1] = array[:,:,1].T

# %%
np.save("field_measured", v_field)

# %%
plt.contourf(v_field[:,:,0])

# %%
from matplotlib.patches import Circle

dx = 0.0028
R = 0.05/dx
fig, ax = plt.subplots()
ax.contourf(var[0][1][0])
circle = Circle((525, 270), radius=R, color='red', fill=True)
ax.add_patch(circle)

plt.show()

# %%
mean_vel = np.sqrt(np.power(v_field[:,:,0], 2) + np.power(v_field[:,:,1],2))

# %%
dx = 0.0028
R = 0.05/dx
fig, ax = plt.subplots()
ax.contourf(mean_vel)
circle = Circle((533, 268), radius=R, color='red', fill=True, alpha=0.3)
ax.add_patch(circle)

plt.show()

# %%
out_file = 'measure_field_magnitude.png'
out_path = f"file/images/{out_file}"

fig, ax = plt.subplots(dpi=150)  # Set dpi to match pixel size

ax.imshow(mean_vel, cmap='viridis', interpolation='nearest')
ax.set_axis_off()
plt.savefig(out_path, bbox_inches='tight', pad_inches=0, transparent=True, dpi=148)
plt.close()
